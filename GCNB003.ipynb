# %% [markdown]
# <a href="https://colab.research.google.com/github/Nendoroids/Colab/blob/main/GCNB003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title **Server 01 - Json Links Extractor Script**
# Server 01! - link = f'https://pwjarvis.onrender.com?v=https://d1d34p8vz63oiq.cloudfront.net/{clec}/master.mpd&quality=720'
# Server 02! - link = f'https://pwjarvis-6de1b4f57cf5.herokuapp.com/?v=https://penpencilvod.pc.cdn.bitgravity.com/{clec}/master.mpd&quality=720'
# Server 03! - link = f'https://pw.jarviis.workers.dev?v=https://d1d34p8vz63oiq.cloudfront.net/{clec}/master.mpd&quality=720'
# Server 04! - link = f'https://api.pwjarvis.tech?v={code}&quality=720'
# Server 05! - link = f'https://api2.pwjarvis.tech?v={code}&quality=720'

import json
from google.colab import files

dict1 = {}
dict2 = {}

json1 = json.loads(str(input("Enter LEC Json Here : ")))
json2 = json.loads(str(input("Enter DPP Json Here : ")))

for data1 in json1["data"]:

  cstr = data1["tags"][0]["name"]
  chap = cstr.replace('+',' ')
  chap = chap.replace('-',' ')
  chap = chap.replace('_',' ')
  chap = chap.replace('*',' ')
  chap = chap.replace('!',' ')
  chap = chap.replace('@',' ')
  chap = chap.replace('#',' ')
  chap = chap.replace('$',' ')
  chap = chap.replace('%',' ')
  chap = chap.replace('^',' ')
  chap = chap.replace('&',' ')
  chap = chap.replace(':',' ')
  chap = chap.replace('<',' ')
  chap = chap.replace('>',' ')
  chap = chap.replace('?',' ')
  chap = chap.replace(';',' ')
  chap = chap.replace(',',' ')
  chap = chap.replace('.',' ')
  chap = chap.replace('(',' ')
  chap = chap.replace(')',' ')
  chap = chap.replace('[',' ')
  chap = chap.replace(']',' ')
  chap = chap.replace('{',' ')
  chap = chap.replace('}',' ')
  chap = chap.replace('=',' ')
  chap = chap.replace('|',' ')
  chap = ' '.join(chap.split())

  nstr = data1["topic"]
  nlec = nstr.replace('+',' ')
  nlec = nlec.replace('-',' ')
  nlec = nlec.replace('_',' ')
  nlec = nlec.replace('*',' ')
  nlec = nlec.replace('!',' ')
  nlec = nlec.replace('@',' ')
  nlec = nlec.replace('#',' ')
  nlec = nlec.replace('$',' ')
  nlec = nlec.replace('%',' ')
  nlec = nlec.replace('^',' ')
  nlec = nlec.replace('&',' ')
  nlec = nlec.replace(':',' ')
  nlec = nlec.replace('<',' ')
  nlec = nlec.replace('>',' ')
  nlec = nlec.replace('?',' ')
  nlec = nlec.replace(';',' ')
  nlec = nlec.replace(',',' ')
  nlec = nlec.replace('.',' ')
  nlec = nlec.replace('(',' ')
  nlec = nlec.replace(')',' ')
  nlec = nlec.replace('[',' ')
  nlec = nlec.replace(']',' ')
  nlec = nlec.replace('{',' ')
  nlec = nlec.replace('}',' ')
  nlec = nlec.replace('=',' ')
  nlec = nlec.replace('|',' ')
  nlec = ' '.join(nlec.split())

  clec  = data1["url"][38:74:1]
  link1 = f'https://pwjarvis.onrender.com?v=https://d1d34p8vz63oiq.cloudfront.net/{clec}/master.mpd&quality=720'
  dict1[nlec] = link1

for data2 in json2["data"]:

  nstr = data2["topic"]
  ndpp = nstr.replace('+',' ')
  ndpp = ndpp.replace('-',' ')
  ndpp = ndpp.replace('_',' ')
  ndpp = ndpp.replace('*',' ')
  ndpp = ndpp.replace('!',' ')
  ndpp = ndpp.replace('@',' ')
  ndpp = ndpp.replace('#',' ')
  ndpp = ndpp.replace('$',' ')
  ndpp = ndpp.replace('%',' ')
  ndpp = ndpp.replace('^',' ')
  ndpp = ndpp.replace('&',' ')
  ndpp = ndpp.replace(':',' ')
  ndpp = ndpp.replace('<',' ')
  ndpp = ndpp.replace('>',' ')
  ndpp = ndpp.replace('?',' ')
  ndpp = ndpp.replace(';',' ')
  ndpp = ndpp.replace(',',' ')
  ndpp = ndpp.replace('.',' ')
  ndpp = ndpp.replace('(',' ')
  ndpp = ndpp.replace(')',' ')
  ndpp = ndpp.replace('[',' ')
  ndpp = ndpp.replace(']',' ')
  ndpp = ndpp.replace('{',' ')
  ndpp = ndpp.replace('}',' ')
  ndpp = ndpp.replace('=',' ')
  ndpp = ndpp.replace('|',' ')
  ndpp = ' '.join(ndpp.split())

  cdpp  = data2["url"][38:74:1]
  link2 = f'https://pwjarvis.onrender.com?v=https://d1d34p8vz63oiq.cloudfront.net/{cdpp}/master.mpd&quality=720'
  dict2[ndpp] = link2

fill = ''
fill += f'@echo off\n'
fill += f'setlocal enabledelayedexpansion\n'
fill += f'\nset "chapter={chap}"\n\n'
fill += f'mkdir "!chapter!" >nul 2>nul\n'
fill += f'cd "!chapter!"\n'
fill += f'mkdir "Lecture" >nul 2>nul\n'

for i, (keys, values) in enumerate(reversed(dict1.items()),start=1):
  fill += f'\nset "name{i}={keys}"\n'
  fill += f'set "vurl{i}={values}"\n'
  fill += f'if not exist "Lecture\!name{i}!.mp4" (\n'
  fill += f'    rmdir /s /q "!name{i}!" >nul 2>nul\n'
  fill += f'    del master.m3u8 >nul 2>nul\n'
  fill += f'    title Download Initiated.. !name{i}!.mp4\n'
  fill += f'    echo.\n'
  fill += f'    echo  Processing.. {chap} - {keys}\n'
  fill += f'    echo.\n'
  fill += f'    curl -X GET "!vurl{i}!" -o "master.m3u8"\n'
  if i < 10:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "L0{i}"\n'
  else:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "L{i}"\n'
  fill += f'    del master.m3u8\n'
  fill += f'    cls\n'
  fill += f') else (\n'
  fill += f'    echo Lecture exists, !name{i}! skipping downloading.\n'
  fill += f')\n'

for i, (keys, values) in enumerate(reversed(dict2.items()),start=1):
  fill += f'\nset "name{i}={keys}"\n'
  fill += f'set "vurl{i}={values}"\n'
  fill += f'if not exist "Lecture\!name{i}!.mp4" (\n'
  fill += f'    rmdir /s /q "!name{i}!" >nul 2>nul\n'
  fill += f'    del master.m3u8 >nul 2>nul\n'
  fill += f'    title Download Initiated.. !name{i}!.mp4\n'
  fill += f'    echo.\n'
  fill += f'    echo  Processing.. {chap} - {keys}\n'
  fill += f'    echo.\n'
  fill += f'    curl -X GET "!vurl{i}!" -o "master.m3u8"\n'
  if i < 10:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "D0{i}"\n'
  else:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "D{i}"\n'
  fill += f'    del master.m3u8\n'
  fill += f'    cls\n'
  fill += f') else (\n'
  fill += f'    echo Lecture exists, !name{i}! skipping downloading.\n'
  fill += f')\n'

with open(f'{chap}.bat','w') as f:
  f.write(fill)
files.download(f'/content/{chap}.bat')

# %%
# @title **Server 02 - Json Links Extractor Script**
# Server 01! - link = f'https://pwjarvis.onrender.com?v=https://d1d34p8vz63oiq.cloudfront.net/{clec}/master.mpd&quality=720'
# Server 02! - link = f'https://pwjarvis-6de1b4f57cf5.herokuapp.com/?v=https://penpencilvod.pc.cdn.bitgravity.com/{clec}/master.mpd&quality=720'
# Server 03! - link = f'https://pw.jarviis.workers.dev?v=https://d1d34p8vz63oiq.cloudfront.net/{clec}/master.mpd&quality=720'
# Server 04! - link = f'https://api.pwjarvis.tech?v={code}&quality=720'
# Server 05! - link = f'https://api2.pwjarvis.tech?v={code}&quality=720'

import json
from google.colab import files

dict1 = {}
dict2 = {}

json1 = json.loads(str(input("Enter LEC Json Here : ")))
json2 = json.loads(str(input("Enter DPP Json Here : ")))

for data1 in json1["data"]:

  cstr = data1["tags"][0]["name"]
  chap = cstr.replace('+',' ')
  chap = chap.replace('-',' ')
  chap = chap.replace('_',' ')
  chap = chap.replace('*',' ')
  chap = chap.replace('!',' ')
  chap = chap.replace('@',' ')
  chap = chap.replace('#',' ')
  chap = chap.replace('$',' ')
  chap = chap.replace('%',' ')
  chap = chap.replace('^',' ')
  chap = chap.replace('&',' ')
  chap = chap.replace(':',' ')
  chap = chap.replace('<',' ')
  chap = chap.replace('>',' ')
  chap = chap.replace('?',' ')
  chap = chap.replace(';',' ')
  chap = chap.replace(',',' ')
  chap = chap.replace('.',' ')
  chap = chap.replace('(',' ')
  chap = chap.replace(')',' ')
  chap = chap.replace('[',' ')
  chap = chap.replace(']',' ')
  chap = chap.replace('{',' ')
  chap = chap.replace('}',' ')
  chap = chap.replace('=',' ')
  chap = chap.replace('|',' ')
  chap = ' '.join(chap.split())

  nstr = data1["topic"]
  nlec = nstr.replace('+',' ')
  nlec = nlec.replace('-',' ')
  nlec = nlec.replace('_',' ')
  nlec = nlec.replace('*',' ')
  nlec = nlec.replace('!',' ')
  nlec = nlec.replace('@',' ')
  nlec = nlec.replace('#',' ')
  nlec = nlec.replace('$',' ')
  nlec = nlec.replace('%',' ')
  nlec = nlec.replace('^',' ')
  nlec = nlec.replace('&',' ')
  nlec = nlec.replace(':',' ')
  nlec = nlec.replace('<',' ')
  nlec = nlec.replace('>',' ')
  nlec = nlec.replace('?',' ')
  nlec = nlec.replace(';',' ')
  nlec = nlec.replace(',',' ')
  nlec = nlec.replace('.',' ')
  nlec = nlec.replace('(',' ')
  nlec = nlec.replace(')',' ')
  nlec = nlec.replace('[',' ')
  nlec = nlec.replace(']',' ')
  nlec = nlec.replace('{',' ')
  nlec = nlec.replace('}',' ')
  nlec = nlec.replace('=',' ')
  nlec = nlec.replace('|',' ')
  nlec = ' '.join(nlec.split())

  clec  = data1["url"][38:74:1]
  link1 = f'https://pwjarvis-6de1b4f57cf5.herokuapp.com/?v=https://penpencilvod.pc.cdn.bitgravity.com/{clec}/master.mpd&quality=720'
  dict1[nlec] = link1

for data2 in json2["data"]:

  nstr = data2["topic"]
  ndpp = nstr.replace('+',' ')
  ndpp = ndpp.replace('-',' ')
  ndpp = ndpp.replace('_',' ')
  ndpp = ndpp.replace('*',' ')
  ndpp = ndpp.replace('!',' ')
  ndpp = ndpp.replace('@',' ')
  ndpp = ndpp.replace('#',' ')
  ndpp = ndpp.replace('$',' ')
  ndpp = ndpp.replace('%',' ')
  ndpp = ndpp.replace('^',' ')
  ndpp = ndpp.replace('&',' ')
  ndpp = ndpp.replace(':',' ')
  ndpp = ndpp.replace('<',' ')
  ndpp = ndpp.replace('>',' ')
  ndpp = ndpp.replace('?',' ')
  ndpp = ndpp.replace(';',' ')
  ndpp = ndpp.replace(',',' ')
  ndpp = ndpp.replace('.',' ')
  ndpp = ndpp.replace('(',' ')
  ndpp = ndpp.replace(')',' ')
  ndpp = ndpp.replace('[',' ')
  ndpp = ndpp.replace(']',' ')
  ndpp = ndpp.replace('{',' ')
  ndpp = ndpp.replace('}',' ')
  ndpp = ndpp.replace('=',' ')
  ndpp = ndpp.replace('|',' ')
  ndpp = ' '.join(ndpp.split())

  cdpp  = data2["url"][38:74:1]
  link2 = f'https://pwjarvis-6de1b4f57cf5.herokuapp.com/?v=https://penpencilvod.pc.cdn.bitgravity.com/{cdpp}/master.mpd&quality=720'
  dict2[ndpp] = link2

fill = ''
fill += f'@echo off\n'
fill += f'setlocal enabledelayedexpansion\n'
fill += f'\nset "chapter={chap}"\n\n'
fill += f'mkdir "!chapter!" >nul 2>nul\n'
fill += f'cd "!chapter!"\n'
fill += f'mkdir "Lecture" >nul 2>nul\n'

for i, (keys, values) in enumerate(reversed(dict1.items()),start=1):
  fill += f'\nset "name{i}={keys}"\n'
  fill += f'set "vurl{i}={values}"\n'
  fill += f'if not exist "Lecture\!name{i}!.mp4" (\n'
  fill += f'    rmdir /s /q "!name{i}!" >nul 2>nul\n'
  fill += f'    del master.m3u8 >nul 2>nul\n'
  fill += f'    title Download Initiated.. !name{i}!.mp4\n'
  fill += f'    echo.\n'
  fill += f'    echo  Processing.. {chap} - {keys}\n'
  fill += f'    echo.\n'
  fill += f'    curl -X GET "!vurl{i}!" -o "master.m3u8"\n'
  if i < 10:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "L0{i}"\n'
  else:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "L{i}"\n'
  fill += f'    del master.m3u8\n'
  fill += f'    cls\n'
  fill += f') else (\n'
  fill += f'    echo Lecture exists, !name{i}! skipping downloading.\n'
  fill += f')\n'

for i, (keys, values) in enumerate(reversed(dict2.items()),start=1):
  fill += f'\nset "name{i}={keys}"\n'
  fill += f'set "vurl{i}={values}"\n'
  fill += f'if not exist "Lecture\!name{i}!.mp4" (\n'
  fill += f'    rmdir /s /q "!name{i}!" >nul 2>nul\n'
  fill += f'    del master.m3u8 >nul 2>nul\n'
  fill += f'    title Download Initiated.. !name{i}!.mp4\n'
  fill += f'    echo.\n'
  fill += f'    echo  Processing.. {chap} - {keys}\n'
  fill += f'    echo.\n'
  fill += f'    curl -X GET "!vurl{i}!" -o "master.m3u8"\n'
  if i < 10:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "D0{i}"\n'
  else:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "D{i}"\n'
  fill += f'    del master.m3u8\n'
  fill += f'    cls\n'
  fill += f') else (\n'
  fill += f'    echo Lecture exists, !name{i}! skipping downloading.\n'
  fill += f')\n'

with open(f'{chap}.bat','w') as f:
  f.write(fill)
files.download(f'/content/{chap}.bat')

# %%
# @title **Server 03 - Json Links Extractor Script**
# Server 01! - link = f'https://pwjarvis.onrender.com?v=https://d1d34p8vz63oiq.cloudfront.net/{clec}/master.mpd&quality=720'
# Server 02! - link = f'https://pwjarvis-6de1b4f57cf5.herokuapp.com/?v=https://penpencilvod.pc.cdn.bitgravity.com/{clec}/master.mpd&quality=720'
# Server 03! - link = f'https://pw.jarviis.workers.dev?v=https://d1d34p8vz63oiq.cloudfront.net/{clec}/master.mpd&quality=720'
# Server 04! - link = f'https://api.pwjarvis.tech?v={code}&quality=720'
# Server 05! - link = f'https://api2.pwjarvis.tech?v={code}&quality=720'

import json
from google.colab import files

dict1 = {}
dict2 = {}

json1 = json.loads(str(input("Enter LEC Json Here : ")))
json2 = json.loads(str(input("Enter DPP Json Here : ")))

for data1 in json1["data"]:

  cstr = data1["tags"][0]["name"]
  chap = cstr.replace('+',' ')
  chap = chap.replace('-',' ')
  chap = chap.replace('_',' ')
  chap = chap.replace('*',' ')
  chap = chap.replace('!',' ')
  chap = chap.replace('@',' ')
  chap = chap.replace('#',' ')
  chap = chap.replace('$',' ')
  chap = chap.replace('%',' ')
  chap = chap.replace('^',' ')
  chap = chap.replace('&',' ')
  chap = chap.replace(':',' ')
  chap = chap.replace('<',' ')
  chap = chap.replace('>',' ')
  chap = chap.replace('?',' ')
  chap = chap.replace(';',' ')
  chap = chap.replace(',',' ')
  chap = chap.replace('.',' ')
  chap = chap.replace('(',' ')
  chap = chap.replace(')',' ')
  chap = chap.replace('[',' ')
  chap = chap.replace(']',' ')
  chap = chap.replace('{',' ')
  chap = chap.replace('}',' ')
  chap = chap.replace('=',' ')
  chap = chap.replace('|',' ')
  chap = ' '.join(chap.split())

  nstr = data1["topic"]
  nlec = nstr.replace('+',' ')
  nlec = nlec.replace('-',' ')
  nlec = nlec.replace('_',' ')
  nlec = nlec.replace('*',' ')
  nlec = nlec.replace('!',' ')
  nlec = nlec.replace('@',' ')
  nlec = nlec.replace('#',' ')
  nlec = nlec.replace('$',' ')
  nlec = nlec.replace('%',' ')
  nlec = nlec.replace('^',' ')
  nlec = nlec.replace('&',' ')
  nlec = nlec.replace(':',' ')
  nlec = nlec.replace('<',' ')
  nlec = nlec.replace('>',' ')
  nlec = nlec.replace('?',' ')
  nlec = nlec.replace(';',' ')
  nlec = nlec.replace(',',' ')
  nlec = nlec.replace('.',' ')
  nlec = nlec.replace('(',' ')
  nlec = nlec.replace(')',' ')
  nlec = nlec.replace('[',' ')
  nlec = nlec.replace(']',' ')
  nlec = nlec.replace('{',' ')
  nlec = nlec.replace('}',' ')
  nlec = nlec.replace('=',' ')
  nlec = nlec.replace('|',' ')
  nlec = ' '.join(nlec.split())

  clec  = data1["url"][38:74:1]
  link1 = f'https://pw.jarviis.workers.dev?v=https://d1d34p8vz63oiq.cloudfront.net/{clec}/master.mpd&quality=720'
  dict1[nlec] = link1

for data2 in json2["data"]:

  nstr = data2["topic"]
  ndpp = nstr.replace('+',' ')
  ndpp = ndpp.replace('-',' ')
  ndpp = ndpp.replace('_',' ')
  ndpp = ndpp.replace('*',' ')
  ndpp = ndpp.replace('!',' ')
  ndpp = ndpp.replace('@',' ')
  ndpp = ndpp.replace('#',' ')
  ndpp = ndpp.replace('$',' ')
  ndpp = ndpp.replace('%',' ')
  ndpp = ndpp.replace('^',' ')
  ndpp = ndpp.replace('&',' ')
  ndpp = ndpp.replace(':',' ')
  ndpp = ndpp.replace('<',' ')
  ndpp = ndpp.replace('>',' ')
  ndpp = ndpp.replace('?',' ')
  ndpp = ndpp.replace(';',' ')
  ndpp = ndpp.replace(',',' ')
  ndpp = ndpp.replace('.',' ')
  ndpp = ndpp.replace('(',' ')
  ndpp = ndpp.replace(')',' ')
  ndpp = ndpp.replace('[',' ')
  ndpp = ndpp.replace(']',' ')
  ndpp = ndpp.replace('{',' ')
  ndpp = ndpp.replace('}',' ')
  ndpp = ndpp.replace('=',' ')
  ndpp = ndpp.replace('|',' ')
  ndpp = ' '.join(ndpp.split())

  cdpp  = data2["url"][38:74:1]
  link2 = f'https://pw.jarviis.workers.dev?v=https://d1d34p8vz63oiq.cloudfront.net/{cdpp}/master.mpd&quality=720'
  dict2[ndpp] = link2

fill = ''
fill += f'@echo off\n'
fill += f'setlocal enabledelayedexpansion\n'
fill += f'\nset "chapter={chap}"\n\n'
fill += f'mkdir "!chapter!" >nul 2>nul\n'
fill += f'cd "!chapter!"\n'
fill += f'mkdir "Lecture" >nul 2>nul\n'

for i, (keys, values) in enumerate(reversed(dict1.items()),start=1):
  fill += f'\nset "name{i}={keys}"\n'
  fill += f'set "vurl{i}={values}"\n'
  fill += f'if not exist "Lecture\!name{i}!.mp4" (\n'
  fill += f'    rmdir /s /q "!name{i}!" >nul 2>nul\n'
  fill += f'    del master.m3u8 >nul 2>nul\n'
  fill += f'    title Download Initiated.. !name{i}!.mp4\n'
  fill += f'    echo.\n'
  fill += f'    echo  Processing.. {chap} - {keys}\n'
  fill += f'    echo.\n'
  fill += f'    curl -X GET "!vurl{i}!" -o "master.m3u8"\n'
  if i < 10:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "L0{i}"\n'
  else:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "L{i}"\n'
  fill += f'    del master.m3u8\n'
  fill += f'    cls\n'
  fill += f') else (\n'
  fill += f'    echo Lecture exists, !name{i}! skipping downloading.\n'
  fill += f')\n'

for i, (keys, values) in enumerate(reversed(dict2.items()),start=1):
  fill += f'\nset "name{i}={keys}"\n'
  fill += f'set "vurl{i}={values}"\n'
  fill += f'if not exist "Lecture\!name{i}!.mp4" (\n'
  fill += f'    rmdir /s /q "!name{i}!" >nul 2>nul\n'
  fill += f'    del master.m3u8 >nul 2>nul\n'
  fill += f'    title Download Initiated.. !name{i}!.mp4\n'
  fill += f'    echo.\n'
  fill += f'    echo  Processing.. {chap} - {keys}\n'
  fill += f'    echo.\n'
  fill += f'    curl -X GET "!vurl{i}!" -o "master.m3u8"\n'
  if i < 10:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "D0{i}"\n'
  else:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "D{i}"\n'
  fill += f'    del master.m3u8\n'
  fill += f'    cls\n'
  fill += f') else (\n'
  fill += f'    echo Lecture exists, !name{i}! skipping downloading.\n'
  fill += f')\n'

with open(f'{chap}.bat','w') as f:
  f.write(fill)
files.download(f'/content/{chap}.bat')

# %%
# @title **Server 04 - Json Links Extractor Script**
# Server 01! - link = f'https://pwjarvis.onrender.com?v=https://d1d34p8vz63oiq.cloudfront.net/{code}/master.mpd&quality=720"'
# Server 02! - link = f'https://pwjarvis-6de1b4f57cf5.herokuapp.com/?v=https://penpencilvod.pc.cdn.bitgravity.com/{code}/master.mpd&quality=720"'
# Server 03! - link = f'https://pw.jarviis.workers.dev?v=https://d1d34p8vz63oiq.cloudfront.net/{code}/master.mpd&quality=720'
# Server 04! - link = f'https://api.pwjarvis.tech?v={code}&quality=720'
# Server 05! - link = f'https://api2.pwjarvis.tech?v={code}&quality=720'

import json
from google.colab import files

dict1 = {}
dict2 = {}

json1 = json.loads(str(input("Enter LEC Json Here : ")))
json2 = json.loads(str(input("Enter DPP Json Here : ")))

for data1 in json1["data"]:

  cstr = data1["tags"][0]["name"]
  chap = cstr.replace('+',' ')
  chap = chap.replace('-',' ')
  chap = chap.replace('_',' ')
  chap = chap.replace('*',' ')
  chap = chap.replace('!',' ')
  chap = chap.replace('@',' ')
  chap = chap.replace('#',' ')
  chap = chap.replace('$',' ')
  chap = chap.replace('%',' ')
  chap = chap.replace('^',' ')
  chap = chap.replace('&',' ')
  chap = chap.replace(':',' ')
  chap = chap.replace('<',' ')
  chap = chap.replace('>',' ')
  chap = chap.replace('?',' ')
  chap = chap.replace(';',' ')
  chap = chap.replace(',',' ')
  chap = chap.replace('.',' ')
  chap = chap.replace('(',' ')
  chap = chap.replace(')',' ')
  chap = chap.replace('[',' ')
  chap = chap.replace(']',' ')
  chap = chap.replace('{',' ')
  chap = chap.replace('}',' ')
  chap = chap.replace('=',' ')
  chap = chap.replace('|',' ')
  chap = ' '.join(chap.split())

  nstr = data1["topic"]
  nlec = nstr.replace('+',' ')
  nlec = nlec.replace('-',' ')
  nlec = nlec.replace('_',' ')
  nlec = nlec.replace('*',' ')
  nlec = nlec.replace('!',' ')
  nlec = nlec.replace('@',' ')
  nlec = nlec.replace('#',' ')
  nlec = nlec.replace('$',' ')
  nlec = nlec.replace('%',' ')
  nlec = nlec.replace('^',' ')
  nlec = nlec.replace('&',' ')
  nlec = nlec.replace(':',' ')
  nlec = nlec.replace('<',' ')
  nlec = nlec.replace('>',' ')
  nlec = nlec.replace('?',' ')
  nlec = nlec.replace(';',' ')
  nlec = nlec.replace(',',' ')
  nlec = nlec.replace('.',' ')
  nlec = nlec.replace('(',' ')
  nlec = nlec.replace(')',' ')
  nlec = nlec.replace('[',' ')
  nlec = nlec.replace(']',' ')
  nlec = nlec.replace('{',' ')
  nlec = nlec.replace('}',' ')
  nlec = nlec.replace('=',' ')
  nlec = nlec.replace('|',' ')
  nlec = ' '.join(nlec.split())

  clec  = data1["url"][38:74:1]
  link1 = f'https://api.pwjarvis.tech?v={clec}&quality=720'
  dict1[nlec] = link1

for data2 in json2["data"]:

  nstr = data2["topic"]
  ndpp = nstr.replace('+',' ')
  ndpp = ndpp.replace('-',' ')
  ndpp = ndpp.replace('_',' ')
  ndpp = ndpp.replace('*',' ')
  ndpp = ndpp.replace('!',' ')
  ndpp = ndpp.replace('@',' ')
  ndpp = ndpp.replace('#',' ')
  ndpp = ndpp.replace('$',' ')
  ndpp = ndpp.replace('%',' ')
  ndpp = ndpp.replace('^',' ')
  ndpp = ndpp.replace('&',' ')
  ndpp = ndpp.replace(':',' ')
  ndpp = ndpp.replace('<',' ')
  ndpp = ndpp.replace('>',' ')
  ndpp = ndpp.replace('?',' ')
  ndpp = ndpp.replace(';',' ')
  ndpp = ndpp.replace(',',' ')
  ndpp = ndpp.replace('.',' ')
  ndpp = ndpp.replace('(',' ')
  ndpp = ndpp.replace(')',' ')
  ndpp = ndpp.replace('[',' ')
  ndpp = ndpp.replace(']',' ')
  ndpp = ndpp.replace('{',' ')
  ndpp = ndpp.replace('}',' ')
  ndpp = ndpp.replace('=',' ')
  ndpp = ndpp.replace('|',' ')
  ndpp = ' '.join(ndpp.split())

  cdpp  = data2["url"][38:74:1]
  link2 = f'https://api.pwjarvis.tech?v={cdpp}&quality=720'
  dict2[ndpp] = link2

fill = ''
fill += f'@echo off\n'
fill += f'setlocal enabledelayedexpansion\n'
fill += f'\nset "chapter={chap}"\n\n'
fill += f'mkdir "!chapter!" >nul 2>nul\n'
fill += f'cd "!chapter!"\n'
fill += f'mkdir "Lecture" >nul 2>nul\n'

for i, (keys, values) in enumerate(reversed(dict1.items()),start=1):
  fill += f'\nset "name{i}={keys}"\n'
  fill += f'set "vurl{i}={values}"\n'
  fill += f'if not exist "Lecture\!name{i}!.mp4" (\n'
  fill += f'    rmdir /s /q "!name{i}!" >nul 2>nul\n'
  fill += f'    del master.m3u8 >nul 2>nul\n'
  fill += f'    title Download Initiated.. !name{i}!.mp4\n'
  fill += f'    echo.\n'
  fill += f'    echo  Processing.. {chap} - {keys}\n'
  fill += f'    echo.\n'
  fill += f'    curl -X GET "!vurl{i}!" -o "master.m3u8"\n'
  if i < 10:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "L0{i}"\n'
  else:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "L{i}"\n'
  fill += f'    del master.m3u8\n'
  fill += f'    cls\n'
  fill += f') else (\n'
  fill += f'    echo Lecture exists, !name{i}! skipping downloading.\n'
  fill += f')\n'

for i, (keys, values) in enumerate(reversed(dict2.items()),start=1):
  fill += f'\nset "name{i}={keys}"\n'
  fill += f'set "vurl{i}={values}"\n'
  fill += f'if not exist "Lecture\!name{i}!.mp4" (\n'
  fill += f'    rmdir /s /q "!name{i}!" >nul 2>nul\n'
  fill += f'    del master.m3u8 >nul 2>nul\n'
  fill += f'    title Download Initiated.. !name{i}!.mp4\n'
  fill += f'    echo.\n'
  fill += f'    echo  Processing.. {chap} - {keys}\n'
  fill += f'    echo.\n'
  fill += f'    curl -X GET "!vurl{i}!" -o "master.m3u8"\n'
  if i < 10:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "D0{i}"\n'
  else:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "D{i}"\n'
  fill += f'    del master.m3u8\n'
  fill += f'    cls\n'
  fill += f') else (\n'
  fill += f'    echo Lecture exists, !name{i}! skipping downloading.\n'
  fill += f')\n'

with open(f'{chap}.bat','w') as f:
  f.write(fill)
files.download(f'/content/{chap}.bat')

# %%
# @title **Server 05 - Json Links Extractor Script**
# Server 01! - link = f'https://pwjarvis.onrender.com?v=https://d1d34p8vz63oiq.cloudfront.net/{code}/master.mpd&quality=720"'
# Server 02! - link = f'https://pwjarvis-6de1b4f57cf5.herokuapp.com/?v=https://penpencilvod.pc.cdn.bitgravity.com/{code}/master.mpd&quality=720"'
# Server 03! - link = f'https://pw.jarviis.workers.dev?v=https://d1d34p8vz63oiq.cloudfront.net/{code}/master.mpd&quality=720'
# Server 04! - link = f'https://api.pwjarvis.tech?v={code}&quality=720'
# Server 05! - link = f'https://api2.pwjarvis.tech?v={code}&quality=720'

import json
from google.colab import files

dict1 = {}
dict2 = {}

json1 = json.loads(str(input("Enter LEC Json Here : ")))
json2 = json.loads(str(input("Enter DPP Json Here : ")))

for data1 in json1["data"]:

  cstr = data1["tags"][0]["name"]
  chap = cstr.replace('+',' ')
  chap = chap.replace('-',' ')
  chap = chap.replace('_',' ')
  chap = chap.replace('*',' ')
  chap = chap.replace('!',' ')
  chap = chap.replace('@',' ')
  chap = chap.replace('#',' ')
  chap = chap.replace('$',' ')
  chap = chap.replace('%',' ')
  chap = chap.replace('^',' ')
  chap = chap.replace('&',' ')
  chap = chap.replace(':',' ')
  chap = chap.replace('<',' ')
  chap = chap.replace('>',' ')
  chap = chap.replace('?',' ')
  chap = chap.replace(';',' ')
  chap = chap.replace(',',' ')
  chap = chap.replace('.',' ')
  chap = chap.replace('(',' ')
  chap = chap.replace(')',' ')
  chap = chap.replace('[',' ')
  chap = chap.replace(']',' ')
  chap = chap.replace('{',' ')
  chap = chap.replace('}',' ')
  chap = chap.replace('=',' ')
  chap = chap.replace('|',' ')
  chap = ' '.join(chap.split())

  nstr = data1["topic"]
  nlec = nstr.replace('+',' ')
  nlec = nlec.replace('-',' ')
  nlec = nlec.replace('_',' ')
  nlec = nlec.replace('*',' ')
  nlec = nlec.replace('!',' ')
  nlec = nlec.replace('@',' ')
  nlec = nlec.replace('#',' ')
  nlec = nlec.replace('$',' ')
  nlec = nlec.replace('%',' ')
  nlec = nlec.replace('^',' ')
  nlec = nlec.replace('&',' ')
  nlec = nlec.replace(':',' ')
  nlec = nlec.replace('<',' ')
  nlec = nlec.replace('>',' ')
  nlec = nlec.replace('?',' ')
  nlec = nlec.replace(';',' ')
  nlec = nlec.replace(',',' ')
  nlec = nlec.replace('.',' ')
  nlec = nlec.replace('(',' ')
  nlec = nlec.replace(')',' ')
  nlec = nlec.replace('[',' ')
  nlec = nlec.replace(']',' ')
  nlec = nlec.replace('{',' ')
  nlec = nlec.replace('}',' ')
  nlec = nlec.replace('=',' ')
  nlec = nlec.replace('|',' ')
  nlec = ' '.join(nlec.split())

  clec  = data1["url"][38:74:1]
  link1 = f'https://api2.pwjarvis.tech?v={clec}&quality=720'
  dict1[nlec] = link1

for data2 in json2["data"]:

  nstr = data2["topic"]
  ndpp = nstr.replace('+',' ')
  ndpp = ndpp.replace('-',' ')
  ndpp = ndpp.replace('_',' ')
  ndpp = ndpp.replace('*',' ')
  ndpp = ndpp.replace('!',' ')
  ndpp = ndpp.replace('@',' ')
  ndpp = ndpp.replace('#',' ')
  ndpp = ndpp.replace('$',' ')
  ndpp = ndpp.replace('%',' ')
  ndpp = ndpp.replace('^',' ')
  ndpp = ndpp.replace('&',' ')
  ndpp = ndpp.replace(':',' ')
  ndpp = ndpp.replace('<',' ')
  ndpp = ndpp.replace('>',' ')
  ndpp = ndpp.replace('?',' ')
  ndpp = ndpp.replace(';',' ')
  ndpp = ndpp.replace(',',' ')
  ndpp = ndpp.replace('.',' ')
  ndpp = ndpp.replace('(',' ')
  ndpp = ndpp.replace(')',' ')
  ndpp = ndpp.replace('[',' ')
  ndpp = ndpp.replace(']',' ')
  ndpp = ndpp.replace('{',' ')
  ndpp = ndpp.replace('}',' ')
  ndpp = ndpp.replace('=',' ')
  ndpp = ndpp.replace('|',' ')
  ndpp = ' '.join(ndpp.split())

  cdpp  = data2["url"][38:74:1]
  link1 = f'https://api2.pwjarvis.tech?v={cdpp}&quality=720'
  dict2[ndpp] = link2

fill = ''
fill += f'@echo off\n'
fill += f'setlocal enabledelayedexpansion\n'
fill += f'\nset "chapter={chap}"\n\n'
fill += f'mkdir "!chapter!" >nul 2>nul\n'
fill += f'cd "!chapter!"\n'
fill += f'mkdir "Lecture" >nul 2>nul\n'

for i, (keys, values) in enumerate(reversed(dict1.items()),start=1):
  fill += f'\nset "name{i}={keys}"\n'
  fill += f'set "vurl{i}={values}"\n'
  fill += f'if not exist "Lecture\!name{i}!.mp4" (\n'
  fill += f'    rmdir /s /q "!name{i}!" >nul 2>nul\n'
  fill += f'    del master.m3u8 >nul 2>nul\n'
  fill += f'    title Download Initiated.. !name{i}!.mp4\n'
  fill += f'    echo.\n'
  fill += f'    echo  Processing.. {chap} - {keys}\n'
  fill += f'    echo.\n'
  fill += f'    curl -X GET "!vurl{i}!" -o "master.m3u8"\n'
  if i < 10:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "L0{i}"\n'
  else:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "L{i}"\n'
  fill += f'    del master.m3u8\n'
  fill += f'    cls\n'
  fill += f') else (\n'
  fill += f'    echo Lecture exists, !name{i}! skipping downloading.\n'
  fill += f')\n'

for i, (keys, values) in enumerate(reversed(dict2.items()),start=1):
  fill += f'\nset "name{i}={keys}"\n'
  fill += f'set "vurl{i}={values}"\n'
  fill += f'if not exist "Lecture\!name{i}!.mp4" (\n'
  fill += f'    rmdir /s /q "!name{i}!" >nul 2>nul\n'
  fill += f'    del master.m3u8 >nul 2>nul\n'
  fill += f'    title Download Initiated.. !name{i}!.mp4\n'
  fill += f'    echo.\n'
  fill += f'    echo  Processing.. {chap} - {keys}\n'
  fill += f'    echo.\n'
  fill += f'    curl -X GET "!vurl{i}!" -o "master.m3u8"\n'
  if i < 10:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "D0{i}"\n'
  else:
    fill += f'    N_m3u8DL-RE.exe "master.m3u8" --save-dir "Lecture" --save-name "D{i}"\n'
  fill += f'    del master.m3u8\n'
  fill += f'    cls\n'
  fill += f') else (\n'
  fill += f'    echo Lecture exists, !name{i}! skipping downloading.\n'
  fill += f')\n'

with open(f'{chap}.bat','w') as f:
  f.write(fill)
files.download(f'/content/{chap}.bat')
